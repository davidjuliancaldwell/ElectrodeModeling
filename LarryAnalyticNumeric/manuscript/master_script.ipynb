% %%
%% resistivity analysis 
%
% David.J.Caldwell 9.26.2018
close all;clear all;clc

% %%
%% load in the data and define common constants 
prepare_data
workingDirec = pwd;
plotIt = 0;
saveIt = 0;

% %%
%% symmetrize the data
symmetrize_data

%% 4 point histograms for the individual

%%%%%%%%%%%%%%%%%%  upper low cut off for gaussian mixture model %%%%%%%%%%
lowerCut = 2;
upperCut = 5;
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

four_point_histograms_individual
%% fit the individual subject data with one rhoA 

fit_individual_global

%% fit the individual subject data with rhoA for different bins
fit_individual

%% 4 point histograms for the symmetrized data

%%%%%%%%%%%%%%%%%% which symmetrized data to use? %%%%%%%%%%%%%%%%%%%%%%%%%
dataInt = gridDataAvg; % this just selects the averaged data
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%

four_point_histograms_symmetrized 
%% fit the averaged data (defined as dataInt above) with one rhoA
fit_symmetrized_global 

%% fit the averaged data (defined as dataInt above) with rhoA by bins
fit_symmetrized
% Out:
%
% ----------------------------------------------------------------------
% The maximum number of colors for table *RdBu* is 11
% The new colormap will be extrapolated from these 11 values
% ----------------------------------------------------------------------
%
% Warning: INTERP1(...,'CUBIC') will change in a future release. Use INTERP1(...,'PCHIP') instead.
% > In interp1>sanitycheckmethod (line 241)
%   In interp1>parseinputs (line 376)
%   In interp1 (line 78)
%   In interpolate_cbrewer (line 31)
%   In cbrewer (line 101)
%   In symmetrize_data (line 10)
% Warning: INTERP1(...,'CUBIC') will change in a future release. Use INTERP1(...,'PCHIP') instead.
% > In interp1>sanitycheckmethod (line 241)
%   In interp1>parseinputs (line 376)
%   In interp1 (line 78)
%   In interpolate_cbrewer (line 32)
%   In cbrewer (line 101)
%   In symmetrize_data (line 10)
% Warning: INTERP1(...,'CUBIC') will change in a future release. Use INTERP1(...,'PCHIP') instead.
% > In interp1>sanitycheckmethod (line 241)
%   In interp1>parseinputs (line 376)
%   In interp1 (line 78)
%   In interpolate_cbrewer (line 33)
%   In cbrewer (line 101)
%   In symmetrize_data (line 10)
% Warning: Failed to converge in 100 iterations for gmdistribution with 2 components
% > In gmcluster (line 202)
%   In gmdistribution.fit (line 102)
%   In fitgmdist (line 135)
%   In four_point_histograms_individual (line 67)
% Warning: Failed to converge in 100 iterations for gmdistribution with 2 components
% > In gmcluster (line 202)
%   In gmdistribution.fit (line 102)
%   In fitgmdist (line 135)
%   In four_point_histograms_individual (line 67)
% complete for subject 1 rhoA = 3.3109 offset = -0.00048072
%  complete for subject 2 rhoA = 2.7553 offset = 0.00015189
%  complete for subject 3 rhoA = 2.8843 offset = -0.0022861
%  complete for subject 4 rhoA = 2.6597 offset = -0.00074367
%  complete for subject 5 rhoA = 2.6052 offset = 0.00070392
%  complete for subject 6 rhoA = 4.7738 offset = -0.0011054
%  complete for subject 7 rhoA = 3.1067 offset = -0.0016412
%  complete for subject 1 rhoA = 3.263004      3.340639      3.570323      3.693854      4.704191       2.92765           NaN offset = 0.006095976  -0.002158332  -0.001870566  -0.001261067  -0.001066221   -0.00181835           NaN
%  Warning: Regression design matrix is rank deficient to within machine precision.
% > In classreg.regr.CompactTermsRegression/checkDesignRank (line 35)
%   In LinearModel.fit (line 1236)
%   In fitlm (line 121)
%   In distance_selection_MSE_bins_fitlm (line 22)
%   In fit_individual (line 44)
% complete for subject 2 rhoA = 2.6915      2.9656      3.7952      3.9431       3.896      3.7226           0 offset = 0.0012223  0.00035224 -0.00060321 -0.00039083 -0.00026401 -0.00012472  0.00044427
%  Warning: Regression design matrix is rank deficient to within machine precision.
% > In classreg.regr.CompactTermsRegression/checkDesignRank (line 35)
%   In LinearModel.fit (line 1236)
%   In fitlm (line 121)
%   In distance_selection_MSE_bins_fitlm (line 22)
%   In fit_individual (line 44)
% complete for subject 3 rhoA = 2.8031      3.2819      3.2805      3.8963      4.7123      4.5155           0 offset = 0.00069956   -0.002616  -0.0029174  -0.0011266  -0.0021138  -0.0024825  -0.0051684
%  complete for subject 4 rhoA = 2.6351      2.7006      3.1265      3.2471      3.6629      3.6898      3.7132 offset = -0.0021049  -0.0009163 -0.00063128 -0.00045235 -0.00042886 -0.00035841 -0.00031667
%  complete for subject 5 rhoA = 2.3513      2.5616      2.6992      3.5408      3.2009      3.1378      0.6327 offset = -0.0094289   0.0012195   0.0021411   0.0032269   0.0026955   0.0023064  0.00019287
%  complete for subject 6 rhoA = 4.4427      3.2342      3.7124      3.8065      4.3784      1.8433       2.167 offset = 0.003503   0.0060695   0.0024813  0.00073121  -0.0011272  2.3778e-05  -0.0007134
%  complete for subject 7 rhoA = 2.7109      1.6081      1.6339      2.2797      2.4539      2.3942      2.2656 offset = -0.010822  -0.0063463  -0.0036111  -0.0018783  -0.0011562 -0.00093425 -0.00072922
%  Warning: Failed to converge in 100 iterations for gmdistribution with 2 components
% > In gmcluster (line 202)
%   In gmdistribution.fit (line 102)
%   In fitgmdist (line 135)
%   In four_point_histograms_symmetrized (line 53)
% complete for symmetric  rhoA =3.0861 offsetSym = -0.16893
%  complete for symmetric  rhoA =3.0306      3.1436      3.5523      3.7686      3.1566      2.5128      1.9219      1.6698 offsetSym = 1.1926    -0.55609    -0.45674    -0.21177    -0.14697    -0.20179    -0.25469     -0.3255
